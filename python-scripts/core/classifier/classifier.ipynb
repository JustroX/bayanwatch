# %% [markdown]
# # Classification

# %% [markdown]
# ## Extract key figures

# %%
import re
import requests

def extract_politicans(data):
    title = data.get('title')
    description = data.get('description')
    maintext = data.get('maintext')

    content = f"""
        <instructions>
            List the names of the most important persons mentioned in the article.
            Output only the names, no need to provide any additional information.
            
            <output_format>
                1. <FirstName> <LastName>, <Suffix>
                2. <FirstName> <LastName>, <Suffix>
                ...
            </output_format>

        </instructions>
        <headline>{title}</headline>
        <description>{description}</description>
        <content>{maintext}</content>
    """

    url = 'http://100.68.153.101:11434/api/generate'
    response = requests.post(url, json={
        'model': 'llama3',
        'prompt': content,
        'stream': False
    })
    
    text = response.json()['response'];
    lines = text.strip().split('\n')
    unique_names = set()

    pattern = r'^\d+\.\s*([^,\n]+(?:\s+[^,\n]+)*)'
    for line in lines:
        matches = re.findall(pattern, line)
        for match in matches:
            unique_names.add(match.strip())
    
    sorted_names = sorted(unique_names)
    return sorted_names

    
dataset_with_politicians = []
def main(input_file):
    with open(input_file, 'r') as infile:
        for line in infile:
            if line:
                m = {}
                exec("data = "+line.strip(), m)
                data = m['data']
                persons = extract_politicans(data)
                
                for name in persons:
                    print(name)

                dataset_with_politicians.append({
                    'title': data.get('title'),
                    'description': data.get('description'),
                    'maintext': data.get('maintext'),
                    'politicians': persons,
                    'source_domain': data.get('source_domain') if data.get('source_domain') else 'smninewschannel.com'
                })

main("files/articles.txt")
# Out:
# Ferdinand Marcos Jr.
# Ferdinand Marcos Jr.
# Lucas Bersamin
# Donald Trump
# Ferdinand Marcos Jr.
# Kamala Harris
# Kiefer Ravena
# LeBron James
# Sara Duterte
# Alejandro Tengco
# Cesar Chavez
# Ferdinand Marcos Jr.
# Joel Anthony Viado
# Jonvic Remulla
# Juan Ponce Enrile
# Katrina Ponce Enrile
# Menardo Guevarra
# Winston Casio
# Ferdinand Marcos Jr.
# Chiz Escudero
# Ferdinand Marcos Jr.
# Imee Marcos
# Sara Duterte
# Apollo Quiboloy
# Chiz Escudero
# Ferdinand Marcos Jr.
# Israelito Torreon
# J-Hope
# Leni Robredo
# Liam Payne
# Lorraine Badoy
# Rodrigo Duterte
# Sara Duterte
# Jonathan Keith Flores
# Luistro (first name not mentioned)
# Michael Poa
# Nolasco Mempin
# Sara Duterte
# Ernesto Dionisio Jr.
# Gloria Camora
# Joel Chua
# Sara Duterte
# Edward Fajarda
# Gina Acosta
# Joel Chua
# Juleita Villadelrey
# Lemuel Ortonio
# Rosalynne Sanchez
# Sara Duterte
# Zuleika Lopez
# Bam Aquino
# Leni Robredo
# Benigno Paolo "Bam" Aquino
# Camille Villar
# Chiz Escudero
# Ferdinand Marcos Jr.
# Leni Robredo
# Lito Lapid
# Tito Sotto
# Analiza Tabujara-Soriano
# Eugenio Jose "Bong" Lacson
# Ferdenand "Bongbong Gorilla" Diego
# Gabriel Bordado Jr.
# Jesse Robredo
# John Barry Tayam
# John Rey Tabujara
# Jurry Nabaja
# Leni Robredo
# Paul Octaviano
# Vicente Perez
# Bong Revilla
# Ferdinand Marcos Jr.
# Gabriel Bordado Jr.
# Jesse Robredo
# Leni Robredo
# Nelson Legacion
# Leni Robredo
# Ferdinand Marcos Jr.
# Salvador Panelo
# Risa Hontiveros
# Rodrigo Duterte
# Sara Duterte
# Bong Go
# Nestor D. Natanauan
# Ferdinand 'Bongbong' Marcos Jr.
# Jericho Petilla
# Leni Robredo
# Sainbuyan Amarsaikhan
# Sara Duterte
# Ferdinand R. Marcos
# Rodrigo Roa Duterte
# Salvador Panelo
# Apollo C. Quiboloy
# Israelito Torreon
# Risa Hontiveros
# Apollo C. Quiboloy
# Bongbong Marcos
# Carlo Catiil
# Sara Duterte
# Ferdinand Bongbong Marcos
# Leni Robredo
# Sara Duterte
# Sara Duterte

# %%
def get_sentiment(data, politician):
    title = data.get('title')
    description = data.get('description')
    maintext = data.get('maintext')

    content = f"""
        <instructions>
            Determine whether the article presents {politician}
            in a positive or negative light, if not mentioned, assume NEUTRAL.

            Output only the sentiment, no need to provide any additional information.

            <output_format>
                POSITIVE
            </output_format>

            <output_format>
                NEGATIVE
            </output_format>

            <output_format>
                NEUTRAL
            </output_format>
        </instructions>
        <politician>{politician}</politician>
        <article>
            <headline>{title}</headline>
            <description>{description}</description>
            <content>{maintext}</content>
        </article>
    """

    url = 'http://100.68.153.101:11434/api/generate'
    response = requests.post(url, json={
        'model': 'llama3',
        'prompt': content,
        'stream': False
    })
    return response.json()['response']

dataset_with_sentiments = []
for data in dataset_with_politicians:
    sentiments = []
    for politician in data['politicians']:
        sentiment = get_sentiment(data, politician)
        print(f"{politician}: {sentiment}")
        sentiments.append((politician, sentiment))

    dataset_with_sentiments.append({
        'title': data.get('title'),
        'description': data.get('description'),
        'maintext': data.get('maintext'),
        'source_domain': data.get('source_domain'),
        'sentiments': sentiments
    })
# Out:
# Ferdinand Marcos Jr.: NEGATIVE
# Ferdinand Marcos Jr.: POSITIVE
# Lucas Bersamin: NEUTRAL
# Donald Trump: NEGATIVE
# Ferdinand Marcos Jr.: NEUTRAL
# Kamala Harris: POSITIVE
# Kiefer Ravena: NEUTRAL
# LeBron James: POSITIVE
# Sara Duterte: NEUTRAL
# Alejandro Tengco: POSITIVE
# Cesar Chavez: POSITIVE
# Ferdinand Marcos Jr.: POSITIVE
# Joel Anthony Viado: POSITIVE
# Jonvic Remulla: POSITIVE
# Juan Ponce Enrile: NEUTRAL
# Katrina Ponce Enrile: NEUTRAL
# Menardo Guevarra: NEUTRAL
# Winston Casio: POSITIVE
# Ferdinand Marcos Jr.: NEGATIVE
# Chiz Escudero: NEGATIVE
# Ferdinand Marcos Jr.: NEGATIVE
# Imee Marcos: NEUTRAL
# Sara Duterte: NEGATIVE
# Apollo Quiboloy: NEUTRAL
# Chiz Escudero: POSITIVE
# Ferdinand Marcos Jr.: NEUTRAL
# Israelito Torreon: NEUTRAL
# J-Hope: POSITIVE
# Leni Robredo: NEUTRAL
# Liam Payne: NEGATIVE
# Lorraine Badoy: NEGATIVE
# Rodrigo Duterte: NEUTRAL
# Sara Duterte: NEUTRAL
# Jonathan Keith Flores: POSITIVE
# Luistro (first name not mentioned): NEUTRAL
# Michael Poa: NEUTRAL
# Nolasco Mempin: NEUTRAL
# Sara Duterte: NEGATIVE
# Ernesto Dionisio Jr.: NEUTRAL
# Gloria Camora: NEUTRAL
# Joel Chua: POSITIVE
# Sara Duterte: NEUTRAL
# Ferdinand R. Marcos Jr.: POSITIVE
# Alice Guo-Risa Hontiveros: NEGATIVE
# Ferdinand Marcos Jr.: NEUTRAL
# Salvador Panelo: POSITIVE
# Risa Hontiveros: NEGATIVE
# Rodrigo Duterte: POSITIVE
# Sara Duterte: POSITIVE
# Bong Go: POSITIVE
# Nestor D. Natanauan: POSITIVE
# Ferdinand 'Bongbong' Marcos Jr.: POSITIVE
# Jericho Petilla: NEUTRAL
# Leni Robredo: NEGATIVE
# Sainbuyan Amarsaikhan: NEUTRAL
# Sara Duterte: POSITIVE
# Ferdinand R. Marcos: POSITIVE
# Rodrigo Roa Duterte: POSITIVE
# Salvador Panelo: POSITIVE
# Apollo C. Quiboloy: NEGATIVE
# Israelito Torreon: NEUTRAL
# Risa Hontiveros: POSITIVE
# Apollo C. Quiboloy: NEUTRAL
# Bongbong Marcos: NEGATIVE
# Carlo Catiil: NEUTRAL
# Sara Duterte: POSITIVE
# Ferdinand Bongbong Marcos: POSITIVE
# Leni Robredo: POSITIVE
# Sara Duterte: POSITIVE
# Sara Duterte: POSITIVE

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
from collections import Counter

sentiments = []
for data in dataset_with_sentiments:
    for politician, sentiment in data['sentiments']:
        sentiments.append({
            'title': data.get('title'),
            'description': data.get('description'),
            'sentiment': sentiment,
            'source': data.get('source_domain'),
            'politician': politician
        })


sentiments
# Out:
# [{'title': "Reality check? Marcos admits flood control infra 'not enough'",
#   'description': 'After saying that over 5,500 flood control projects have been completed at the time of his third SONA, Marcos has to face the flooding problem squarely in the wake of Severe Tropical Storm Kristine',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Marcos declares November 4 as day of national mourning for Kristine victims',
#   'description': "'The national flag shall be flown at half-mast from sunrise to sunset on all government buildings and installations across the country and abroad,' the Presidential Communications Office says",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Marcos declares November 4 as day of national mourning for Kristine victims',
#   'description': "'The national flag shall be flown at half-mast from sunrise to sunset on all government buildings and installations across the country and abroad,' the Presidential Communications Office says",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Lucas Bersamin'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Donald Trump'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Kamala Harris'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Kiefer Ravena'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'LeBron James'},
#  {'title': "Marcos says he'd 'rather not' comment on Sara Duterte's tirades",
#   'description': "Today's headlines: Marcos & Duterte, Lebron James, Kiefer Ravena",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Alejandro Tengco'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Cesar Chavez'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Joel Anthony Viado'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Jonvic Remulla'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Juan Ponce Enrile'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Katrina Ponce Enrile'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Menardo Guevarra'},
#  {'title': "With no EO, freeports and ecozones 'gray area' in Marcos POGO ban",
#   'description': "One big ecozone that can issue its own license is CEZA, run by Katrina Ponce Enrile, daughter of Marcos' chief counsel",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Winston Casio'},
#  {'title': '‘I’d rather not’: Again, Marcos skips comment on VP Duterte’s tirades',
#   'description': "Would the President comment on\xa0the Vice President's threat to excavate the late dictator's remains? 'I'd rather not,' says Marcos.",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': "'Unbecoming of a VP'",
#   'description': 'Senate President Chiz Escudero says the Vice President should have been more cirmcumspect in releasing public statements',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Chiz Escudero'},
#  {'title': "'Unbecoming of a VP'",
#   'description': 'Senate President Chiz Escudero says the Vice President should have been more cirmcumspect in releasing public statements',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': "'Unbecoming of a VP'",
#   'description': 'Senate President Chiz Escudero says the Vice President should have been more cirmcumspect in releasing public statements',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Imee Marcos'},
#  {'title': "'Unbecoming of a VP'",
#   'description': 'Senate President Chiz Escudero says the Vice President should have been more cirmcumspect in releasing public statements',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Apollo Quiboloy'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Chiz Escudero'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Israelito Torreon'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'J-Hope'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Liam Payne'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Lorraine Badoy'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Rodrigo Duterte'},
#  {'title': 'Another DepEd exec admits receiving cash from Sara Duterte | The wRap',
#   'description': 'Today’s headlines: Sara Duterte, BTS’ J-Hope, Liam Payne',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Did the VP Sara-led DepEd mislead COA into believing it funded AFP youth summits?',
#   'description': 'During a House hearing, the Sara Duterte-led Department of Education is questioned over use of AFP documents and events, not funded by DepEd, to justify its confidential expenses',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Jonathan Keith Flores'},
#  {'title': 'Did the VP Sara-led DepEd mislead COA into believing it funded AFP youth summits?',
#   'description': 'During a House hearing, the Sara Duterte-led Department of Education is questioned over use of AFP documents and events, not funded by DepEd, to justify its confidential expenses',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Luistro (first name not mentioned)'},
#  {'title': 'Did the VP Sara-led DepEd mislead COA into believing it funded AFP youth summits?',
#   'description': 'During a House hearing, the Sara Duterte-led Department of Education is questioned over use of AFP documents and events, not funded by DepEd, to justify its confidential expenses',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Michael Poa'},
#  {'title': 'Did the VP Sara-led DepEd mislead COA into believing it funded AFP youth summits?',
#   'description': 'During a House hearing, the Sara Duterte-led Department of Education is questioned over use of AFP documents and events, not funded by DepEd, to justify its confidential expenses',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Nolasco Mempin'},
#  {'title': 'Did the VP Sara-led DepEd mislead COA into believing it funded AFP youth summits?',
#   'description': 'During a House hearing, the Sara Duterte-led Department of Education is questioned over use of AFP documents and events, not funded by DepEd, to justify its confidential expenses',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': "Sara Duterte-led OVP's expensive rental of safe houses flagged",
#   'description': '(UPDATED) One receipt indicates that the OVP, in 2022, could have spent as high as P250,000 per day to rent a safe house, dwarfing the cost of an overnight stay in most five-star hotels in the Philippines',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ernesto Dionisio Jr.'},
#  {'title': "Sara Duterte-led OVP's expensive rental of safe houses flagged",
#   'description': '(UPDATED) One receipt indicates that the OVP, in 2022, could have spent as high as P250,000 per day to rent a safe house, dwarfing the cost of an overnight stay in most five-star hotels in the Philippines',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Gloria Camora'},
#  {'title': "Sara Duterte-led OVP's expensive rental of safe houses flagged",
#   'description': '(UPDATED) One receipt indicates that the OVP, in 2022, could have spent as high as P250,000 per day to rent a safe house, dwarfing the cost of an overnight stay in most five-star hotels in the Philippines',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Joel Chua'},
#  {'title': "Sara Duterte-led OVP's expensive rental of safe houses flagged",
#   'description': '(UPDATED) One receipt indicates that the OVP, in 2022, could have spent as high as P250,000 per day to rent a safe house, dwarfing the cost of an overnight stay in most five-star hotels in the Philippines',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Edward Fajarda'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Gina Acosta'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Joel Chua'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Juleita Villadelrey'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Lemuel Ortonio'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Rosalynne Sanchez'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': "VP Sara Duterte's staff snub House inquiry, say hearing 'unnecessary'",
#   'description': "House good government committee chairman Joel Chua insists that Congress has the discretion to summon 'executive officials who are most familiar with' executive operations",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Zuleika Lopez'},
#  {'title': 'Leni Robredo warns vs fake solicitations for Naga',
#   'description': 'The former vice president says she and her Angat Buhay NGO have authorized only the Kaya Natin! Movement to receive cash donations on behalf of her team in Naga',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Bam Aquino'},
#  {'title': 'Leni Robredo warns vs fake solicitations for Naga',
#   'description': 'The former vice president says she and her Angat Buhay NGO have authorized only the Kaya Natin! Movement to receive cash donations on behalf of her team in Naga',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Benigno Paolo "Bam" Aquino'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Camille Villar'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Chiz Escudero'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Lito Lapid'},
#  {'title': 'In Bicol, rivals Marcos and Robredo exchange quick hellos',
#   'description': 'For the first time in eight years, the two politicians — rivals both in 2016 and 2022 — meet in Robredo’s home turf Bicol',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Tito Sotto'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Analiza Tabujara-Soriano'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Eugenio Jose "Bong" Lacson'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdenand "Bongbong Gorilla" Diego'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Gabriel Bordado Jr.'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Jesse Robredo'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'John Barry Tayam'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'John Rey Tabujara'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Jurry Nabaja'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Paul Octaviano'},
#  {'title': 'COC filing day 4, local races: Leni Robredo’s Team Naga, dynasty challengers',
#   'description': "'New age, new leader,' says a Gen-Z leader who filed his candidacy for the congressional seat of the lone district of Las Piñas",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Vicente Perez'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Bong Revilla'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Gabriel Bordado Jr.'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Jesse Robredo'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Leni Robredo announces Naga City mayor bid',
#   'description': 'The former vice president, whose 2022 presidential run electrified and inspired a last-minute grassroots campaign, now returns to where she’s most at ease: her hometown, Naga City',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Nelson Legacion'},
#  {'title': 'Robredo reactivates Bayanihan E-Konsulta for Typhoon Carina, southwest monsoon victims',
#   'description': 'The third iteration of the volunteer-driven teleconsultation services aims to cater to general medical cases, with a focus on those who need consultations for Leptospirosis prophylaxis',
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Apollo Quiboloy'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Ariel Arias'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'John Rex Laudiangco'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Mark Tolentino'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Oscar Morado'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'Arrested preacher Apollo Quiboloy files candidacy for senator',
#   'description': "(3rd UPDATE) The self-proclaimed 'appointed son of god,' who is currently behind bars, submits his certificate of candidacy through an authorized representative",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Sonny Matula'},
#  {'title': 'Who helped Alice Guo flee from the Philippines?',
#   'description': "While the mastermind behind Alice Guo's escape remains a mystery, senators have dropped some clues. Let's piece them together.",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Alice Guo'},
#  {'title': 'Who helped Alice Guo flee from the Philippines?',
#   'description': "While the mastermind behind Alice Guo's escape remains a mystery, senators have dropped some clues. Let's piece them together.",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Guo Hua Ping'},
#  {'title': 'Who helped Alice Guo flee from the Philippines?',
#   'description': "While the mastermind behind Alice Guo's escape remains a mystery, senators have dropped some clues. Let's piece them together.",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Huang Zhiyang'},
#  {'title': 'Who helped Alice Guo flee from the Philippines?',
#   'description': "While the mastermind behind Alice Guo's escape remains a mystery, senators have dropped some clues. Let's piece them together.",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Jinggoy Estrada'},
#  {'title': 'Who helped Alice Guo flee from the Philippines?',
#   'description': "While the mastermind behind Alice Guo's escape remains a mystery, senators have dropped some clues. Let's piece them together.",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Alice Guo'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Carlito'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Harry Roque'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'James Patrick Cruz'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Katherine Cassandra Ong (also known as Cassy Ong or Cassy Li)'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Sheila'},
#  {'title': 'FACT CHECK: Circulating selfie of Alice Guo, Risa Hontiveros is fake',
#   'description': "'Wala akong kaibigan na pekeng Pilipino. Mag-ingat po sa mga edited photos online na magkasama kami 'di umano at magkaibigan daw kami. This is fake,' says Senator Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Uswag'},
#  {'title': "Hontiveros to seek realignment of Sara Duterte's 'improper' P10-M book fund request",
#   'description': "'I think it's a proper item for realignment,' says Senator Risa Hontiveros",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': "Hontiveros to seek realignment of Sara Duterte's 'improper' P10-M book fund request",
#   'description': "'I think it's a proper item for realignment,' says Senator Risa Hontiveros",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Rappler Recap: Sara Duterte, Risa Hontiveros clash during Senate budget hearing',
#   'description': "Rappler's Bonz Magsambol gives a recap of the Senate deliberations on the 2025 proposed budget of the Office of the Vice President",
#   'sentiment': 'NEUTRAL',
#   'source': 'www.rappler.com',
#   'politician': 'Grace Poe'},
#  {'title': 'Rappler Recap: Sara Duterte, Risa Hontiveros clash during Senate budget hearing',
#   'description': "Rappler's Bonz Magsambol gives a recap of the Senate deliberations on the 2025 proposed budget of the Office of the Vice President",
#   'sentiment': 'POSITIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'Rappler Recap: Sara Duterte, Risa Hontiveros clash during Senate budget hearing',
#   'description': "Rappler's Bonz Magsambol gives a recap of the Senate deliberations on the 2025 proposed budget of the Office of the Vice President",
#   'sentiment': 'NEGATIVE',
#   'source': 'www.rappler.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Marcos declares local holidays for November, December',
#   'description': 'Malacañang on Saturday released a series of Presidential Proclamations declaring special non-working holidays in specific cities and municipalities nationwide for the remaining two months of 2024.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Marcos to ERC: Study possible moratorium on electric bills in areas under state of calamity',
#   'description': 'Marcos tasked the ERC to study the possible implementation of temporary relief to electricity bill payments in areas under a state of calamity.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand Bongbong Marcos Jr.'},
#  {'title': 'Marcos declares Nov. 4 as Day of National Mourning for Kristine victims',
#   'description': 'President Ferdinand Marcos Jr. has declared Monday, November 4, 2024, as a Day of National Mourning for the victims of Severe Tropical Storm Kristine.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'AFP says PMA cadet asked for Marcos watch at graduation; says it’s not common, tradition',
#   'description': 'The Armed Forces of the Philippines (AFP) confirmed that a cadet asked for President Ferdinand Marcos Jr’s wristwatch during a graduation ceremony of the Philippine Military Academy (PMA) in May this year, an incident raised by Vice President Sara Duterte in a press conference last week.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'AFP says PMA cadet asked for Marcos watch at graduation; says it’s not common, tradition',
#   'description': 'The Armed Forces of the Philippines (AFP) confirmed that a cadet asked for President Ferdinand Marcos Jr’s wristwatch during a graduation ceremony of the Philippine Military Academy (PMA) in May this year, an incident raised by Vice President Sara Duterte in a press conference last week.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Francel Margareth Padilla'},
#  {'title': 'AFP says PMA cadet asked for Marcos watch at graduation; says it’s not common, tradition',
#   'description': 'The Armed Forces of the Philippines (AFP) confirmed that a cadet asked for President Ferdinand Marcos Jr’s wristwatch during a graduation ceremony of the Philippine Military Academy (PMA) in May this year, an incident raised by Vice President Sara Duterte in a press conference last week.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Marcos, VP Sara trust ratings dip in latest OCTA survey',
#   'description': 'OCTA Research showed a dip in the trust and performance ratings of Marcos and Duterte.',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand "Bongbong" Marcos Jr.'},
#  {'title': 'Marcos, VP Sara trust ratings dip in latest OCTA survey',
#   'description': 'OCTA Research showed a dip in the trust and performance ratings of Marcos and Duterte.',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Trust ratings nina Pres. Marcos, VP Sara, nabawasan sa latest OCTA survey',
#   'description': 'Kapuwa nabawasan ang trust at performance ratings nina Pangulong Ferdinand “Bongbong” Marcos Jr. at Vice President Sara Duterte sa pinakabagong resulta ng survey ng OCTA Research. Ngunit higit na mas malaki ang nabawas sa pangalawang pangulo.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand “Bongbong” Marcos Jr.'},
#  {'title': 'Trust ratings nina Pres. Marcos, VP Sara, nabawasan sa latest OCTA survey',
#   'description': 'Kapuwa nabawasan ang trust at performance ratings nina Pangulong Ferdinand “Bongbong” Marcos Jr. at Vice President Sara Duterte sa pinakabagong resulta ng survey ng OCTA Research. Ngunit higit na mas malaki ang nabawas sa pangalawang pangulo.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'COA urged to look into Davao City confidential funds under Sara Duterte',
#   'description': 'A lawmaker is urging the Commission on Audit to look into the confidential funds provided to Vice President Sara Duterte when she was mayor of Davao City.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'France Castro'},
#  {'title': 'COA urged to look into Davao City confidential funds under Sara Duterte',
#   'description': 'A lawmaker is urging the Commission on Audit to look into the confidential funds provided to Vice President Sara Duterte when she was mayor of Davao City.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Jonathan Andal'},
#  {'title': 'COA urged to look into Davao City confidential funds under Sara Duterte',
#   'description': 'A lawmaker is urging the Commission on Audit to look into the confidential funds provided to Vice President Sara Duterte when she was mayor of Davao City.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'VP Sara Duterte, inisip na tanggalan ng ulo si Pres. Marcos; bangkay ni Marcos Sr., itatapon sa WPS',
#   'description': 'Inihayag ni Vice President Sara Duterte na napagtanto niya na "toxic" na ang samahan nila ni Pangulong Ferdinand "Bongbong" Marcos Jr. nang pumasok sa isip niya na taggalan ng ulo ang huli dahil sa inis. Nagbanta rin ang pangalawang pangulo na huhukayin ang bangkay ng namayapang si dating Pangulong Marcos Sr. at itatapon ang labi nito sa West Philippine Sea.',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand "Bongbong" Marcos Jr.'},
#  {'title': 'VP Sara Duterte, inisip na tanggalan ng ulo si Pres. Marcos; bangkay ni Marcos Sr., itatapon sa WPS',
#   'description': 'Inihayag ni Vice President Sara Duterte na napagtanto niya na "toxic" na ang samahan nila ni Pangulong Ferdinand "Bongbong" Marcos Jr. nang pumasok sa isip niya na taggalan ng ulo ang huli dahil sa inis. Nagbanta rin ang pangalawang pangulo na huhukayin ang bangkay ng namayapang si dating Pangulong Marcos Sr. at itatapon ang labi nito sa West Philippine Sea.',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Imee Marcos'},
#  {'title': 'VP Sara Duterte, inisip na tanggalan ng ulo si Pres. Marcos; bangkay ni Marcos Sr., itatapon sa WPS',
#   'description': 'Inihayag ni Vice President Sara Duterte na napagtanto niya na "toxic" na ang samahan nila ni Pangulong Ferdinand "Bongbong" Marcos Jr. nang pumasok sa isip niya na taggalan ng ulo ang huli dahil sa inis. Nagbanta rin ang pangalawang pangulo na huhukayin ang bangkay ng namayapang si dating Pangulong Marcos Sr. at itatapon ang labi nito sa West Philippine Sea.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Cynthia Villar'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Ferdinand "Bongbong" Marcos Jr.'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Jesus Crispin Remulla'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Koko Pimentel'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Paolo Ortega'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Romeo Acop'},
#  {'title': 'Ilang mambabatas, nagmungkahi na magpa-psychological evaluation si VP Sara Duterte',
#   'description': 'Nabahala ang ilang mambabatas sa mga naging pahayag ni Vice President Sara Duterte tungkol kay Pangulong Ferdinand "Bongbong" Marcos Jr., na nais niyang putulin ang ulo, at sa banta niyang huhukayin ang bangkay ni dating pangulong Marcos Sr., para itapon sa West Philippine Sea.',
#   'sentiment': 'NEGATIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'DOJ urged to issue lookout bulletin order on OVP officials',
#   'description': 'A lawmaker has asked the Department of Justice (DOJ) to issue an Immigration Lookout Bulletin Order (ILBO) against seven officials of the Office of the Vice President (OVP).',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Isa Avendano-Umali'},
#  {'title': 'DOJ urged to issue lookout bulletin order on OVP officials',
#   'description': 'A lawmaker has asked the Department of Justice (DOJ) to issue an Immigration Lookout Bulletin Order (ILBO) against seven officials of the Office of the Vice President (OVP).',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Jesus Crispin Remulla'},
#  {'title': 'DOJ urged to issue lookout bulletin order on OVP officials',
#   'description': 'A lawmaker has asked the Department of Justice (DOJ) to issue an Immigration Lookout Bulletin Order (ILBO) against seven officials of the Office of the Vice President (OVP).',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Joel Chua'},
#  {'title': 'Ex-VP Leni Robredo files COC for Naga City mayor',
#   'description': 'Former Vice President Leni Robredo on Saturday filed her COC for Naga City mayor.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Gabby Bordado'},
#  {'title': 'Ex-VP Leni Robredo files COC for Naga City mayor',
#   'description': 'Former Vice President Leni Robredo on Saturday filed her COC for Naga City mayor.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Ex-VP Leni Robredo files COC for Naga City mayor',
#   'description': 'Former Vice President Leni Robredo on Saturday filed her COC for Naga City mayor.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Romulo Macalintal'},
#  {'title': "Ex-VP Leni Robredo warns of 'fake number' asking for cash donations",
#   'description': 'Former Vice President Leni Robredo warned the public about a fake number using her name and asking for donations for victims of\xa0Tropical Storm Kristine.',
#   'sentiment': 'POSITIVE',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Areiz Macaraig'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Butch Borja'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Elmer Baldemoro'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Frank Mendoza'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Gabby Bordado'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
#   'description': 'Former Vice President Leni Robredo will run for mayor in Naga City and will formalize her candidacy during the weekend.',
#   'sentiment': 'NEUTRAL',
#   'source': 'www.gmanetwork.com',
#   'politician': 'Gayle Abonal-Gomez'},
#  {'title': 'Leni Robredo announces Naga City mayoral bid',
# ...
#   'politician': 'Harry Roque'},
#  {'title': "Security threats to VP Sara Duterte shouldn’t be compared to ex-VP Leni Robredo's-Atty. Roque",
#   'description': 'THE security situation of Vice President Sara Duterte is different from former Vice President Leni Robredo’s.',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Leni Robredo'},
#  {'title': "Security threats to VP Sara Duterte shouldn’t be compared to ex-VP Leni Robredo's-Atty. Roque",
#   'description': 'THE security situation of Vice President Sara Duterte is different from former Vice President Leni Robredo’s.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Rodrigo Roa Duterte'},
#  {'title': "Security threats to VP Sara Duterte shouldn’t be compared to ex-VP Leni Robredo's-Atty. Roque",
#   'description': 'THE security situation of Vice President Sara Duterte is different from former Vice President Leni Robredo’s.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Trust rating ni Marcos Jr, bumagsak-SWS',
#   'description': 'BUMABA ang trust rating ni Pangulong Bongbong Marcos Jr. ayon sa Social Weather Stations (SWS). Sa resulta ng kanilang September 14',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Bongbong Marcos Jr.'},
#  {'title': 'Trust rating ni Marcos Jr, bumagsak-SWS',
#   'description': 'BUMABA ang trust rating ni Pangulong Bongbong Marcos Jr. ayon sa Social Weather Stations (SWS). Sa resulta ng kanilang September 14',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Sen. Risa Hontiveros advised to study law before criticizing Pastor ACQ',
#   'description': 'RECENTLY, Sen. Risa Hontiveros suggested that the License to Own Firearms should be revoked from Pastor Apollo C. Quiboloy following the..',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Apollo C. Quiboloy'},
#  {'title': 'Sen. Risa Hontiveros advised to study law before criticizing Pastor ACQ',
#   'description': 'RECENTLY, Sen. Risa Hontiveros suggested that the License to Own Firearms should be revoked from Pastor Apollo C. Quiboloy following the..',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Israelito Torreon'},
#  {'title': 'Sen. Risa Hontiveros advised to study law before criticizing Pastor ACQ',
#   'description': 'RECENTLY, Sen. Risa Hontiveros suggested that the License to Own Firearms should be revoked from Pastor Apollo C. Quiboloy following the..',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'VP Sara Duterte, humingi ng paumanhin sa mga taga-KOJC',
#   'description': 'MULING humingi ng tawad si Vice President Sara Duterte sa mga taga-Kingdom of Jesus Christ (KOJC). Ito’y dahil pa rin sa kaniyang naging...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'Legal counsel points out ‘clear evidence’ of guilty judgment by Risa Hontiveros vs Pastor Apollo C. Quiboloy-Legal Counsel',
#   'description': 'PROOF of bias on the part of Senator Risa Hontiveros has emerged in the case involving Pastor Apollo C. Quiboloy.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Apollo C. Quiboloy'},
#  {'title': 'Legal counsel points out ‘clear evidence’ of guilty judgment by Risa Hontiveros vs Pastor Apollo C. Quiboloy-Legal Counsel',
#   'description': 'PROOF of bias on the part of Senator Risa Hontiveros has emerged in the case involving Pastor Apollo C. Quiboloy.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Elvis Balayan'},
#  {'title': 'Legal counsel points out ‘clear evidence’ of guilty judgment by Risa Hontiveros vs Pastor Apollo C. Quiboloy-Legal Counsel',
#   'description': 'PROOF of bias on the part of Senator Risa Hontiveros has emerged in the case involving Pastor Apollo C. Quiboloy.',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'Dating VP Leni Robredo, hindi tatakbong senador sa 2025 elections-Liberal Party',
#   'description': 'HINDI tatakbong senador sa darating na midterm elections sa susunod na taon si dating Vice President Leni Robredo.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Leni Robredo'},
#  {'title': '‘Everyone is welcome in our place’-Ex-VP Leni Robredo sa pagbisita ni VP Sara sa Naga',
#   'description': 'NILINAW ni dating Vice President Leni Robredo na lahat ay welcome sa kanilang lugar tuwing kapistahan ng Peñafrancia.',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Barry Gutierrez'},
#  {'title': '‘Everyone is welcome in our place’-Ex-VP Leni Robredo sa pagbisita ni VP Sara sa Naga',
#   'description': 'NILINAW ni dating Vice President Leni Robredo na lahat ay welcome sa kanilang lugar tuwing kapistahan ng Peñafrancia.',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Bong Revilla'},
#  {'title': '‘Everyone is welcome in our place’-Ex-VP Leni Robredo sa pagbisita ni VP Sara sa Naga',
#   'description': 'NILINAW ni dating Vice President Leni Robredo na lahat ay welcome sa kanilang lugar tuwing kapistahan ng Peñafrancia.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Jesse Robredo'},
#  {'title': '‘Everyone is welcome in our place’-Ex-VP Leni Robredo sa pagbisita ni VP Sara sa Naga',
#   'description': 'NILINAW ni dating Vice President Leni Robredo na lahat ay welcome sa kanilang lugar tuwing kapistahan ng Peñafrancia.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Leni Robredo'},
#  {'title': '‘Everyone is welcome in our place’-Ex-VP Leni Robredo sa pagbisita ni VP Sara sa Naga',
#   'description': 'NILINAW ni dating Vice President Leni Robredo na lahat ay welcome sa kanilang lugar tuwing kapistahan ng Peñafrancia.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'President Marcos to let COMELEC scrutinize signatures for People’s Initiative',
#   'description': 'PRESIDENT Ferdinand R. Marcos, Jr. has received the issue of signature buying for the People’s Initiative (PI). “Well, if the signature...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Ferdinand R. Marcos Jr.'},
#  {'title': 'Mayor Alice Guo-Risa Hontiveros’ new object of oppression',
#   'description': 'SENATOR Risa Hontiveros has a new person to pick on and this is Bamban Mayor Alice Guo. For former Chief Presidential Legal...',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Alice Guo-Risa Hontiveros'},
#  {'title': 'Mayor Alice Guo-Risa Hontiveros’ new object of oppression',
#   'description': 'SENATOR Risa Hontiveros has a new person to pick on and this is Bamban Mayor Alice Guo. For former Chief Presidential Legal...',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Ferdinand Marcos Jr.'},
#  {'title': 'Mayor Alice Guo-Risa Hontiveros’ new object of oppression',
#   'description': 'SENATOR Risa Hontiveros has a new person to pick on and this is Bamban Mayor Alice Guo. For former Chief Presidential Legal...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Salvador Panelo'},
#  {'title': 'Risa Hontiveros, sinupalpal ni dating Pangulong Rodrigo Duterte',
#   'description': 'IPINAMUKHA ni dating Pangulong Rodrigo Roa Duterte kay Sen. Risa Hontiveros na wala itong alam hinggil sa paglutas ng problema sa mga...',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 
',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Salvador Panelo'},
#  {'title': 'Sen. Risa Hontiveros, pinayuhang mag-aral ng batas bago manira vs kay Pastor Apollo C. Quiboloy',
#   'description': 'KAMAKAILAN ay nagsabi si Sen. Risa Hontiveros na dapat ay tanggalan ng license to own firearms si Pastor Apollo C. Quiboloy kasunod ng..',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Apollo C. Quiboloy'},
#  {'title': 'Sen. Risa Hontiveros, pinayuhang mag-aral ng batas bago manira vs kay Pastor Apollo C. Quiboloy',
#   'description': 'KAMAKAILAN ay nagsabi si Sen. Risa Hontiveros na dapat ay tanggalan ng license to own firearms si Pastor Apollo C. Quiboloy kasunod ng..',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Israelito Torreon'},
#  {'title': 'Sen. Risa Hontiveros, pinayuhang mag-aral ng batas bago manira vs kay Pastor Apollo C. Quiboloy',
#   'description': 'KAMAKAILAN ay nagsabi si Sen. Risa Hontiveros na dapat ay tanggalan ng license to own firearms si Pastor Apollo C. Quiboloy kasunod ng..',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Risa Hontiveros'},
#  {'title': 'President Marcos’ silence on the abuse against KOJC members questioned',
#   'description': 'MORE than a week has passed since the overkill arrest warrant served by the police on the religious compounds of the Kingdom of Jesus Christ (KOJC), yet the trauma still lingers among members...',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Apollo C. Quiboloy'},
#  {'title': 'President Marcos’ silence on the abuse against KOJC members questioned',
#   'description': 'MORE than a week has passed since the overkill arrest warrant served by the police on the religious compounds of the Kingdom of Jesus Christ (KOJC), yet the trauma still lingers among members...',
#   'sentiment': 'NEGATIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Bongbong Marcos'},
#  {'title': 'President Marcos’ silence on the abuse against KOJC members questioned',
#   'description': 'MORE than a week has passed since the overkill arrest warrant served by the police on the religious compounds of the Kingdom of Jesus Christ (KOJC), yet the trauma still lingers among members...',
#   'sentiment': 'NEUTRAL',
#   'source': 'smninewschannel.com',
#   'politician': 'Carlo Catiil'},
#  {'title': 'VP Sara Duterte speaks at the 50th Philippine Business Conference and Expo',
#   'description': 'Vice President Sara Duterte speaks at the 50th Philippine Business Conference and Expo organized by the Philippine Chamber of Commerce...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'President Marcos Jr. orders acceleration of common drug production in Philippines',
#   'description': 'PRESIDENT Ferdinand Bongbong Marcos, Jr. is pushing for the swift production and affordability of common drugs in the Philippines. He also...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Ferdinand Bongbong Marcos'},
#  {'title': 'Pagkikita ni VP Sara at Leni Robredo, maituturing na “goodwill”',
#   'description': 'NAGKITA noong nakaraang linggo si Vice President Sara Duterte at dating VP Leni Robredo sa balwarte nito sa Naga City, Bicol.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Leni Robredo'},
#  {'title': 'Pagkikita ni VP Sara at Leni Robredo, maituturing na “goodwill”',
#   'description': 'NAGKITA noong nakaraang linggo si Vice President Sara Duterte at dating VP Leni Robredo sa balwarte nito sa Naga City, Bicol.',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'},
#  {'title': 'VP Sara Duterte, bumisita sa Brgy. Baclaran sa Parañaque',
#   'description': 'BUMISITA si Vice President Inday Sara Duterte sa Barangay Baclaran sa Parañaque kamakailan. Matapos dumalo sa misa sa Baclaran Church...',
#   'sentiment': 'POSITIVE',
#   'source': 'smninewschannel.com',
#   'politician': 'Sara Duterte'}]

# %%
import csv

# Specify the CSV file name
csv_file = 'files/politician_sentiments.csv'

# Write the data to a CSV file
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=sentiments[0].keys())
    writer.writeheader()
    writer.writerows(sentiments)

print(f'Data saved to {csv_file}')
# Out:
# Data saved to files/politician_sentiments.csv
